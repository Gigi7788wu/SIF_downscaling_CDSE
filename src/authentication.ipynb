# %%
import openeo

# %%
connection = openeo.connect(
    "https://openeofed.dataspace.copernicus.eu/"
)

connection.authenticate_oidc()
# Out:
# Visit <a href="https://identity.dataspace.copernicus.eu/auth/realms/CDSE/device?user_code=OEDD-MZHJ" title="Authenticate at https://identity.dataspace.copernicus.eu/auth/realms/CDSE/device?user_code=OEDD-MZHJ" target="_blank" rel="noopener noreferrer">https://identity.dataspace.copernicus.eu/auth/realms/CDSE/device?user_code=OEDD-MZHJ</a> <a href="#" onclick="navigator.clipboard.writeText('https://identity.dataspace.copernicus.eu/auth/realms/CDSE/device?user_code=OEDD-MZHJ');return false;" title="Copy authentication URL to clipboard">&#128203;</a> to authenticate.
# ✅ Authorized successfully
# Authenticated using device code flow.
# <Connection to 'https://openeofed.dataspace.copernicus.eu/openeo/1.2/' with OidcBearerAuth>
